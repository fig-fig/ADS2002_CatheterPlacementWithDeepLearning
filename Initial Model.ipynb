# %% [markdown]
# <a href="https://colab.research.google.com/github/EmKelsall/ADS2002---Catheter-Placement-Project/blob/Ryan/initial_model_working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import keras

print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# ## Preparing the Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filenames = os.listdir("/content/drive/MyDrive/ADS2002-Project-CatheterPlacement/Data/train")

# %%
train_imgs = np.empty((0,2048, 2500))
FileIDs = []

#getting the first 100 images
for i in range(100):
  #Making sure the images are the same pixel size
  img = plt.imread(f"/content/drive/MyDrive/ADS2002-Project-CatheterPlacement/Data/train/{filenames[i]}")
  img_shape = img.shape

  if img_shape == (2048, 2500):
    #Save filename for later
    FileIDs.append(filenames[i])

    #add extra dimension so we can concatenate
    img = np.expand_dims(img,(0))

    #adding to train_imgs array
    train_imgs = np.concatenate((train_imgs, img), axis = 0)

train_imgs.shape
# Out:
# (48, 2048, 2500)

# %%
train_tensor = np.reshape(train_imgs, (48, 2048, 2500, 1))

# %%
# makes img 2x smaller
max_pooling = tf.keras.layers.MaxPooling2D(pool_size = 2, strides = 2, padding = "valid")
pooled_array = max_pooling(train_tensor)

# %%
#extracting just the CVC labels
train_data = pd.read_csv("/content/drive/MyDrive/ADS2002-Project-CatheterPlacement/Data/train.csv")
CVC_train = train_data[["StudyInstanceUID","CVC - Abnormal", "CVC - Borderline", "CVC - Normal"]]
CVC_train.set_index('StudyInstanceUID', inplace=True)
CVC_train.head()
# Out:
#                                                     CVC - Abnormal  \
# StudyInstanceUID
# 1.2.826.0.1.3680043.8.498.266976289532732281893...               0
# 1.2.826.0.1.3680043.8.498.463028915973987587598...               0
# 1.2.826.0.1.3680043.8.498.238192607197484948589...               0
# 1.2.826.0.1.3680043.8.498.682866432023232128012...               1
# 1.2.826.0.1.3680043.8.498.100502030092259382591...               0
#
#                                                     CVC - Borderline  \
# StudyInstanceUID
# 1.2.826.0.1.3680043.8.498.266976289532732281893...                 0
# 1.2.826.0.1.3680043.8.498.463028915973987587598...                 0
# 1.2.826.0.1.3680043.8.498.238192607197484948589...                 1
# 1.2.826.0.1.3680043.8.498.682866432023232128012...                 0
# 1.2.826.0.1.3680043.8.498.100502030092259382591...                 0
#
#                                                     CVC - Normal
# StudyInstanceUID
# 1.2.826.0.1.3680043.8.498.266976289532732281893...             0
# 1.2.826.0.1.3680043.8.498.463028915973987587598...             1
# 1.2.826.0.1.3680043.8.498.238192607197484948589...             0
# 1.2.826.0.1.3680043.8.498.682866432023232128012...             0
# 1.2.826.0.1.3680043.8.498.100502030092259382591...             1

# %%
#cleaning up the labels
UID = []
for i in range(len(FileIDs)):
  UID.append(FileIDs[i].replace(".jpg",""))

UID[0:10]
# Out:
# ['1.2.826.0.1.3680043.8.498.96315500926641444675409331764690933307',
#  '1.2.826.0.1.3680043.8.498.96450515721778915344219421534269786290',
#  '1.2.826.0.1.3680043.8.498.96359554498564333142663951388648557789',
#  '1.2.826.0.1.3680043.8.498.96447675290915183668080373345495953473',
#  '1.2.826.0.1.3680043.8.498.96279880013483713441521686300695558821',
#  '1.2.826.0.1.3680043.8.498.96349754766067875463134738379718157835',
#  '1.2.826.0.1.3680043.8.498.96406955712119661656412685705445497931',
#  '1.2.826.0.1.3680043.8.498.96346896468102014556173811602388995798',
#  '1.2.826.0.1.3680043.8.498.96332366015730959061321671670587275158',
#  '1.2.826.0.1.3680043.8.498.96365165965335417502443200533971674013']

# %%
train_labels = np.empty((0,3))
data = []
for ID in UID:
    data.append(CVC_train.loc[ID])

train_labels_df = pd.DataFrame(data)

train_labels_df = train_labels_df.reindex(UID)

train_labels = train_labels_df.values

# %% [markdown]
# ## Making and training the model

# %%
if np.all(train_labels[1] == [0,0,1]):
  print('hello')
# Out:
# hello

# %%
def get_allignment(labels):
  result = ""
  if np.any(labels == [2,2,1]):
    result += "Normal"

  elif np.any(labels == [2,1,2]):
    result += "Borderline"

  elif np.any(labels == [1,2,2]):
    result += "Abnormal"

  return result

# %%
#displaying 6 of the images in the pooled_imgs array
plt.figure(figsize=(12,9))
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(pooled_array[i], cmap=plt.cm.binary)
  plt.xlabel(get_allignment(train_labels[i]))
plt.show()

# %%
pooled_array[0].shape
# Out:
# TensorShape([1024, 1250, 1])

# %%
lr = 0.000005
epochs=100
img_size = (1024, 1250)

# %%
#initiating the model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=img_size),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(3)
    ])

# %%
#compling the model
optim = keras.optimizers.Adam(learning_rate=lr)
model.compile(optimizer=optim,
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'],)

# %%
#fitting the model
history = model.fit(pooled_array, train_labels, epochs=epochs)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 6s 2s/step - loss: 397.0175 - accuracy: 0.3958
# Epoch 2/100
# 2/2 [==============================] - 3s 1s/step - loss: 855.8772 - accuracy: 0.5833
# Epoch 3/100
# 2/2 [==============================] - 4s 2s/step - loss: 537.0210 - accuracy: 0.5417
# Epoch 4/100
# 2/2 [==============================] - 4s 2s/step - loss: 174.6266 - accuracy: 0.5833
# Epoch 5/100
# 2/2 [==============================] - 3s 1s/step - loss: 122.2074 - accuracy: 0.3542
# Epoch 6/100
# 2/2 [==============================] - 4s 1s/step - loss: 93.0095 - accuracy: 0.5833
# Epoch 7/100
# 2/2 [==============================] - 2s 963ms/step - loss: 253.6956 - accuracy: 0.1667
# Epoch 8/100
# 2/2 [==============================] - 3s 2s/step - loss: 135.1093 - accuracy: 0.5833
# Epoch 9/100
# 2/2 [==============================] - 3s 1s/step - loss: 189.7440 - accuracy: 0.5833
# Epoch 10/100
# 2/2 [==============================] - 3s 1s/step - loss: 126.4880 - accuracy: 0.5208
# Epoch 11/100
# 2/2 [==============================] - 2s 1s/step - loss: 80.6841 - accuracy: 0.4167
# Epoch 12/100
# 2/2 [==============================] - 3s 996ms/step - loss: 58.7510 - accuracy: 0.6042
# Epoch 13/100
# 2/2 [==============================] - 3s 1s/step - loss: 55.3757 - accuracy: 0.4792
# Epoch 14/100
# 2/2 [==============================] - 3s 2s/step - loss: 36.9668 - accuracy: 0.5833
# Epoch 15/100
# 2/2 [==============================] - 2s 964ms/step - loss: 53.7255 - accuracy: 0.6875
# Epoch 16/100
# 2/2 [==============================] - 2s 980ms/step - loss: 43.0521 - accuracy: 0.6667
# Epoch 17/100
# 2/2 [==============================] - 2s 1s/step - loss: 24.4128 - accuracy: 0.6875
# Epoch 18/100
# 2/2 [==============================] - 2s 1s/step - loss: 24.0603 - accuracy: 0.6667
# Epoch 19/100
# 2/2 [==============================] - 4s 2s/step - loss: 19.5048 - accuracy: 0.6458
# Epoch 20/100
# 2/2 [==============================] - 3s 969ms/step - loss: 12.7744 - accuracy: 0.6875
# Epoch 21/100
# 2/2 [==============================] - 2s 1s/step - loss: 22.6980 - accuracy: 0.7292
# Epoch 22/100
# 2/2 [==============================] - 2s 951ms/step - loss: 19.1127 - accuracy: 0.6250
# Epoch 23/100
# 2/2 [==============================] - 2s 965ms/step - loss: 16.9469 - accuracy: 0.6458
# Epoch 24/100
# 2/2 [==============================] - 2s 1s/step - loss: 9.2830 - accuracy: 0.7083
# Epoch 25/100
# 2/2 [==============================] - 4s 2s/step - loss: 15.1006 - accuracy: 0.7292
# Epoch 26/100
# 2/2 [==============================] - 2s 957ms/step - loss: 14.7963 - accuracy: 0.7292
# Epoch 27/100
# 2/2 [==============================] - 2s 970ms/step - loss: 11.8619 - accuracy: 0.6875
# Epoch 28/100
# 2/2 [==============================] - 2s 1s/step - loss: 12.6338 - accuracy: 0.7083
# Epoch 29/100
# 2/2 [==============================] - 2s 957ms/step - loss: 10.1854 - accuracy: 0.8125
# Epoch 30/100
# 2/2 [==============================] - 2s 1s/step - loss: 11.7453 - accuracy: 0.7083
# Epoch 31/100
# 2/2 [==============================] - 4s 2s/step - loss: 9.2501 - accuracy: 0.7917
# Epoch 32/100
# 2/2 [==============================] - 3s 1s/step - loss: 4.1858 - accuracy: 0.7917
# Epoch 33/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.5716 - accuracy: 0.7083
# Epoch 34/100
# 2/2 [==============================] - 2s 954ms/step - loss: 6.7785 - accuracy: 0.7083
# Epoch 35/100
# 2/2 [==============================] - 2s 983ms/step - loss: 12.0349 - accuracy: 0.6250
# Epoch 36/100
# 2/2 [==============================] - 4s 2s/step - loss: 10.0569 - accuracy: 0.6875
# Epoch 37/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.1810 - accuracy: 0.6250
# Epoch 38/100
# 2/2 [==============================] - 3s 1s/step - loss: 16.4667 - accuracy: 0.6250
# Epoch 39/100
# 2/2 [==============================] - 2s 1s/step - loss: 12.5331 - accuracy: 0.7083
# Epoch 40/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.2756 - accuracy: 0.7083
# Epoch 41/100
# 2/2 [==============================] - 3s 1s/step - loss: 20.9390 - accuracy: 0.6667
# Epoch 42/100
# 2/2 [==============================] - 4s 2s/step - loss: 16.4590 - accuracy: 0.6042
# Epoch 43/100
# 2/2 [==============================] - 3s 1s/step - loss: 11.6369 - accuracy: 0.7917
# Epoch 44/100
# 2/2 [==============================] - 2s 964ms/step - loss: 18.6257 - accuracy: 0.6875
# Epoch 45/100
# 2/2 [==============================] - 2s 965ms/step - loss: 5.6847 - accuracy: 0.8333
# Epoch 46/100
# 2/2 [==============================] - 2s 1s/step - loss: 6.4516 - accuracy: 0.8333
# Epoch 47/100
# 2/2 [==============================] - 4s 1s/step - loss: 7.2442 - accuracy: 0.8125
# Epoch 48/100
# 2/2 [==============================] - 2s 965ms/step - loss: 8.5096 - accuracy: 0.7708
# Epoch 49/100
# 2/2 [==============================] - 2s 997ms/step - loss: 10.4557 - accuracy: 0.7083
# Epoch 50/100
# 2/2 [==============================] - 3s 1s/step - loss: 10.7769 - accuracy: 0.7917
# Epoch 51/100
# 2/2 [==============================] - 2s 998ms/step - loss: 15.0131 - accuracy: 0.6667
# Epoch 52/100
# 2/2 [==============================] - 3s 1s/step - loss: 20.2162 - accuracy: 0.6250
# Epoch 53/100
# 2/2 [==============================] - 3s 1s/step - loss: 10.7835 - accuracy: 0.7708
# Epoch 54/100
# 2/2 [==============================] - 2s 970ms/step - loss: 12.0600 - accuracy: 0.7708
# Epoch 55/100
# 2/2 [==============================] - 2s 973ms/step - loss: 13.8154 - accuracy: 0.6875
# Epoch 56/100
# 2/2 [==============================] - 2s 1s/step - loss: 10.0331 - accuracy: 0.8333
# Epoch 57/100
# 2/2 [==============================] - 2s 1s/step - loss: 10.6891 - accuracy: 0.7917
# Epoch 58/100
# 2/2 [==============================] - 5s 2s/step - loss: 9.9800 - accuracy: 0.6875
# Epoch 59/100
# 2/2 [==============================] - 5s 2s/step - loss: 7.3366 - accuracy: 0.7500
# Epoch 60/100
# 2/2 [==============================] - 2s 964ms/step - loss: 10.6622 - accuracy: 0.7917
# Epoch 61/100
# 2/2 [==============================] - 2s 975ms/step - loss: 11.9892 - accuracy: 0.7500
# Epoch 62/100
# 2/2 [==============================] - 2s 971ms/step - loss: 10.8367 - accuracy: 0.7083
# Epoch 63/100
# 2/2 [==============================] - 2s 962ms/step - loss: 8.3898 - accuracy: 0.7917
# Epoch 64/100
# 2/2 [==============================] - 4s 2s/step - loss: 20.5695 - accuracy: 0.6667
# Epoch 65/100
# 2/2 [==============================] - 3s 955ms/step - loss: 11.9919 - accuracy: 0.6875
# Epoch 66/100
# 2/2 [==============================] - 2s 979ms/step - loss: 13.7913 - accuracy: 0.7292
# Epoch 67/100
# 2/2 [==============================] - 2s 966ms/step - loss: 6.7140 - accuracy: 0.8125
# Epoch 68/100
# 2/2 [==============================] - 3s 1s/step - loss: 9.8374 - accuracy: 0.8125
# Epoch 69/100
# 2/2 [==============================] - 4s 2s/step - loss: 4.5649 - accuracy: 0.8333
# Epoch 70/100
# 2/2 [==============================] - 3s 1s/step - loss: 10.4958 - accuracy: 0.7500
# Epoch 71/100
# 2/2 [==============================] - 3s 1s/step - loss: 6.0589 - accuracy: 0.8750
# Epoch 72/100
# 2/2 [==============================] - 2s 974ms/step - loss: 7.3979 - accuracy: 0.8750
# Epoch 73/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.4232 - accuracy: 0.7083
# Epoch 74/100
# 2/2 [==============================] - 3s 1s/step - loss: 10.1944 - accuracy: 0.7917
# Epoch 75/100
# 2/2 [==============================] - 3s 1s/step - loss: 14.7110 - accuracy: 0.6667
# Epoch 76/100
# 2/2 [==============================] - 2s 968ms/step - loss: 24.3729 - accuracy: 0.6875
# Epoch 77/100
# 2/2 [==============================] - 2s 958ms/step - loss: 9.4317 - accuracy: 0.7708
# Epoch 78/100
# 2/2 [==============================] - 2s 964ms/step - loss: 23.3896 - accuracy: 0.7083
# Epoch 79/100
# 2/2 [==============================] - 3s 1s/step - loss: 9.6430 - accuracy: 0.7708
# Epoch 80/100
# 2/2 [==============================] - 3s 1s/step - loss: 10.7553 - accuracy: 0.7708
# Epoch 81/100
# 2/2 [==============================] - 3s 1s/step - loss: 11.5950 - accuracy: 0.7708
# Epoch 82/100
# 2/2 [==============================] - 2s 1s/step - loss: 4.6602 - accuracy: 0.8542
# Epoch 83/100
# 2/2 [==============================] - 3s 1s/step - loss: 6.2187 - accuracy: 0.8125
# Epoch 84/100
# 2/2 [==============================] - 2s 941ms/step - loss: 10.3964 - accuracy: 0.7708
# Epoch 85/100
# 2/2 [==============================] - 2s 1s/step - loss: 8.1115 - accuracy: 0.7917
# Epoch 86/100
# 2/2 [==============================] - 4s 2s/step - loss: 9.7994 - accuracy: 0.7708
# Epoch 87/100
# 2/2 [==============================] - 3s 1s/step - loss: 8.6359 - accuracy: 0.7292
# Epoch 88/100
# 2/2 [==============================] - 2s 968ms/step - loss: 16.8545 - accuracy: 0.7917
# Epoch 89/100
# 2/2 [==============================] - 2s 968ms/step - loss: 8.5134 - accuracy: 0.8125
# Epoch 90/100
# 2/2 [==============================] - 2s 1s/step - loss: 9.3836 - accuracy: 0.7083
# Epoch 91/100
# 2/2 [==============================] - 3s 2s/step - loss: 7.0182 - accuracy: 0.7708
# Epoch 92/100
# 2/2 [==============================] - 3s 1s/step - loss: 6.4453 - accuracy: 0.8750
# Epoch 93/100
# 2/2 [==============================] - 3s 1s/step - loss: 9.0435 - accuracy: 0.8125
# Epoch 94/100
# 2/2 [==============================] - 2s 978ms/step - loss: 9.2163 - accuracy: 0.7083
# Epoch 95/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.2373 - accuracy: 0.7500
# Epoch 96/100
# 2/2 [==============================] - 3s 1s/step - loss: 9.7253 - accuracy: 0.7500
# Epoch 97/100
# 2/2 [==============================] - 4s 2s/step - loss: 10.9290 - accuracy: 0.6875
# Epoch 98/100
# 2/2 [==============================] - 3s 1s/step - loss: 16.4481 - accuracy: 0.7292
# Epoch 99/100
# 2/2 [==============================] - 2s 1s/step - loss: 9.2781 - accuracy: 0.7292
# Epoch 100/100
# 2/2 [==============================] - 2s 954ms/step - loss: 37.2660 - accuracy: 0.6667

# %%
plt.plot(range(1,epochs+1), history.history["accuracy"])
plt.title(f"Accuracy over {epochs} epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy");

# %%
plt.plot(range(1,epochs+1), history.history["loss"])
plt.title(f"Loss over {epochs} epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss");
